# %%
# Linear Regression

# %%
hours = [2,3,4,5,6,7] # x-variate
marks = [42,65,43,76,57,76] # y-variate

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(hours,marks)

# %%
import seaborn as sns

# %%
sns.heatmap(hours,marks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.heatmap(hours,marks)
#
# TypeError: heatmap() takes 1 positional argument but 2 were given

# %%
sns.regplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.regplot(df)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\regression.py:763, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     752 def regplot(
#     753     data=None, *, x=None, y=None,
#     754     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)
#     760     scatter_kws=None, line_kws=None, ax=None
#     761 ):
# --> 763     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     764                                  scatter, fit_reg, ci, n_boot, units, seed,
#     765                                  order, logistic, lowess, robust, logx,
# ...

# %%
import pandas as pd
df = pd.DataFrame(hours, marks)

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
sns.regplot(x=hours, y = marks)
# regression plot
# Out:
# <Axes: >

# %%
# Best Fit - pts v close to the regression line
# Over Fit
# Under Fit

# %%
sns.regplot(x=hours, y = marks, color = 'red')
# regression plot
# Out:
# <Axes: >

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
# ...

# %%
import sklearn.linear_model(SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True)
# Out:
#   Cell In[26], line 1
#     import sklearn.linear_model(SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True)
#                                ^
# SyntaxError: invalid syntax

# %%
SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True

# %%
# Algorithm
regressor = sklearn.linear_model.LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Algorithm
# ----> 2 regressor = sklearn.linear_model.LinearRegression()
#
# NameError: name 'sklearn' is not defined

# %%
regressor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 regressor
#
# NameError: name 'regressor' is not defined

# %%
hours = [[2],[3],[4],[5],[6],[7]] # x-variate
marks = [42,65,43,76,57,76] # y-variate

# %%
#Training the Algorithm
regressor.fit(hours,markss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #Training the Algorithm
# ----> 2 regressor.fit(hours,markss)
#
# NameError: name 'regressor' is not defined

# %%
# pickle

# %%
import pickle as pkl

# %%
pkl.dump(regressor, open('a.pkl'),'wb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pkl.dump(regressor, open('a.pkl'),'wb')
#
# NameError: name 'regressor' is not defined

# %%
# pickling so as it is a component can be used in a different file by depickling

# %%
pkl.dump(regressor, open('a.pkl'),'wb')
x_test = [[4],[3],[4],[5]]

# %%
y_pred = regressor.predict(x_test)

# %%
pkl.dump(regressor, open('a.pkl'),'wb')
hours_test = [[4],[3],[4],[5]]

# %%
marks_pred = regressor.predict(hours_test)
# is Excel's forecast likeS

# %%
marks_pred
